# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_csv("Churn_Modelling.csv")
a
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
a.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
a.replace(["Male","Female"],[0,1],inplace=True)

# %%
a
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France       1   42
# 1             2    15647311       Hill          608     Spain       1   41
# 2             3    15619304       Onio          502    France       1   42
# 3             4    15701354       Boni          699    France       1   39
# 4             5    15737888   Mitchell          850     Spain       1   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France       0   39
# 9996       9997    15569892  Johnstone          516    France       0   35
# 9997       9998    15584532        Liu          709    France       1   36
# 9998       9999    15682355  Sabbatini          772   Germany       0   42
# 9999      10000    15628319     Walker          792    France       1   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
a.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
a.replace(["France","Germany","Spain"],[0,1,2],inplace=True)

# %%
a
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619          0       1   42
# 1             2    15647311       Hill          608          2       1   41
# 2             3    15619304       Onio          502          0       1   42
# 3             4    15701354       Boni          699          0       1   39
# 4             5    15737888   Mitchell          850          2       1   43
# ...         ...         ...        ...          ...        ...     ...  ...
# 9995       9996    15606229   Obijiaku          771          0       0   39
# 9996       9997    15569892  Johnstone          516          0       0   35
# 9997       9998    15584532        Liu          709          0       1   36
# 9998       9999    15682355  Sabbatini          772          1       0   42
# 9999      10000    15628319     Walker          792          0       1   28
#
# ...

# %%
x=a[["CreditScore","Geography","Gender","Age","Tenure","Balance","NumOfProducts","HasCrCard","IsActiveMember","EstimatedSalary"]]
x
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       1   42       2       0.00              1
# 1             608          2       1   41       1   83807.86              1
# 2             502          0       1   42       8  159660.80              3
# 3             699          0       1   39       1       0.00              2
# 4             850          2       1   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       0   39       5       0.00              2
# 9996          516          0       0   35      10   57369.61              1
# 9997          709          0       1   36       7       0.00              1
# 9998          772          1       0   42       3   75075.31              2
# 9999          792          0       1   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y=a.iloc[:,-1:]
y
# Out:
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,shuffle=True,random_state=150)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.naive_bayes import BernoulliNB

# %%
DTC=DecisionTreeClassifier()
KNN=KNeighborsClassifier()
RFC=RandomForestClassifier()
model=LogisticRegression()
BernoulliNB=BernoulliNB()

# %%
DTC.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
DTC.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
DTC.score(xtest,ytest)
# Out:
# 0.782

# %%
KNN.fit(xtrain,ytrain)
# Out:
# C:\Users\Umar\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
KNN.predict(xtest)
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
KNN.score(xtest,ytest)
# Out:
# 0.7785

# %%
RFC.fit(xtrain,ytrain)
# Out:
# <ipython-input-29-087af67e27ac>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC.fit(xtrain,ytrain)
# RandomForestClassifier()

# %%
RFC.predict(xtest)
# Out:
# array([0, 0, 0, ..., 1, 1, 0], dtype=int64)

# %%
RFC.score(xtest,ytest)
# Out:
# 0.868

# %%
model.fit(xtrain,ytrain)
# Out:
# C:\Users\Umar\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
model.predict(xtest)
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
model.score(xtest,ytest)
# Out:
# 0.8115

# %%
BernoulliNB.fit(xtrain,ytrain)
# Out:
# C:\Users\Umar\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# BernoulliNB()

# %%
BernoulliNB.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
BernoulliNB.score(xtest,ytest)
# Out:
# 0.815
